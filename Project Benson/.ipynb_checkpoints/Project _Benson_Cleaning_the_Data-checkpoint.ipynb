# %%
import pandas as pd
import matplotlib as mp
import seaborn as sns
import time

# %%
data1 = pd.read_csv('files/file1.csv')

# %%
data2 = pd.read_csv('files/file2.csv')

# %%
data3 = pd.read_csv('files/file3.csv')

# %%
data4 = pd.read_csv('files/file4.csv')

# %%
data5 = pd.read_csv('files/file5.csv')

# %%
data6 = pd.read_csv('files/file6.csv')

# %%
data7 = pd.read_csv('files/file7.csv')

# %%
data8 = pd.read_csv('files/file8.csv')

# %%
data9 = pd.read_csv('files/file9.csv')

# %%
data10 = pd.read_csv('files/file10.csv')

# %%
data11 = pd.read_csv('files/file11.csv')

# %%
data12 = pd.read_csv('files/file12.csv')

# %%
data13 = pd.read_csv('files/file13.csv')

# %%
data14 = pd.read_csv('files/file14.csv')

# %%
data15 = pd.read_csv('files/file15.csv')

# %%
data16 = pd.read_csv('files/file16.csv')

# %%
frames = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16]

# %%
merg=pd.concat(frames)

# %%
merg['EXITS']=merg['EXITS                                                               ']

# %%
del merg['EXITS                                                               ']

# %%
merg.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/24/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/24/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/24/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/24/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/24/2018  19:00:00
#
#          DESC  ENTRIES    EXITS
# 0  RECOVR AUD  6527780  2210496
# 1     REGULAR  6527794  2210507
# 2     REGULAR  6527838  2210585
# 3     REGULAR  6527994  2210644
# 4     REGULAR  6528278  2210705

# %%
merg.dropna()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/24/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/25/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/25/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/25/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  02/25/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  02/25/2018
# ...

# %%
merg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3154761 entries, 0 to 196977
# Data columns (total 11 columns):
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES     int64
# EXITS       int64
# dtypes: int64(2), object(9)
# memory usage: 288.8+ MB

# %%
merg.to_csv('merg_data.csv')

# %%
merg['Ent'] = merg['ENTRIES'] - merg['ENTRIES'].shift(+1)

# %%
merg['Ext'] = merg['EXITS'] - merg['EXITS'].shift(+1)

# %%
merg.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  19:00:00
#
#          DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  RECOVR AUD  6527780  2210496    NaN   NaN    Saturday      2
# 1     REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 2     REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 3     REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 4     REGULAR  6528278  2210705  284.0  61.0    Saturday      2

# %%
merg.describe()
# Out:
#             ENTRIES         EXITS           Ent           Ext
# count  3.154761e+06  3.154761e+06  3.154760e+06  3.154760e+06
# mean   3.927402e+07  3.232717e+07 -1.139037e+00 -5.779330e-01
# std    2.050674e+08  1.900460e+08  4.288098e+07  3.929465e+07
# min    0.000000e+00  0.000000e+00 -2.117750e+09 -2.145033e+09
# 25%    5.081950e+05  2.482710e+05  9.000000e+00  7.000000e+00
# 50%    2.577976e+06  1.454429e+06  7.400000e+01  5.100000e+01
# 75%    6.890224e+06  4.826487e+06  2.510000e+02  1.700000e+02
# max    2.130068e+09  2.145850e+09  2.122404e+09  2.145033e+09

# %%
merg['DATE']=pd.to_datetime(merg['DATE'])
merg['day_of_week'] = merg['DATE'].dt.weekday_name

# %%
merg['month']=merg['DATE'].dt.month

# %%
merg.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-02-24  19:00:00
#
#          DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  RECOVR AUD  6527780  2210496    NaN   NaN    Saturday      2
# 1     REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 2     REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 3     REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 4     REGULAR  6528278  2210705  284.0  61.0    Saturday      2

# %%
merg.dropna(axis=0)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-26
# ...

# %%
merg.to_csv('merg_data.csv')
