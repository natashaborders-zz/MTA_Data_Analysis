# %%
import pandas as pd
import math
import numpy as np
import matplotlib as mp
import seaborn as sns
import time
from collections import defaultdict as ddict

# %%
def getCutoff(csv_file):
    # read data into a pandas dataframe
    data = pd.read_csv(csv_file)
    
    # Delete all data corresponding to the 'RECOVR AUD' field
    data = data.where(data['DESC'] != 'RECOVR AUD').dropna()
    
    # Create Ent field () and drop NaNs
    data['Ent'] = data['ENTRIES'].diff()
    data = data.dropna(axis=0)
    
    # Drop all negative entries (those don't make sense) and drop NaNs
    data = data.where(data['Ent'] >= 0)
    data = data.dropna(axis = 0)
    
    # Determine number of rows we are ok with losing (one percent of total rows)
    one_pct = math.floor(data.shape[0]/100)
    
    # Determine cutoff (value at which one percent of the entries in the Ent column is over)
    cutoff = 0
    while data[data.Ent > cutoff].count()['Ent'] > target:
        cutoff += 20

    return cutoff

# %%
csv_list = ['180303.csv', '180310.csv', '180317.csv', '180324.csv',
           '180331.csv', '180407.csv', '180414.csv', '180421.csv',
           '180428.csv', '180505.csv', '180512.csv', '180519.csv',
           '180526.csv', '180602.csv', '180609.csv', '180616.csv',
           '180623.csv', '180630.csv']

# %%
# getCutoff('180630.csv')
num_weeks = 0
cutoff_total = 0
cutoff_dict = ddict(int)
for csv in csv_list:
    date = csv.split('.')[0]
    cutoff = getCutoff(csv)
    cutoff_dict[date] = cutoff
    cutoff_total += cutoff
    num_weeks += 1

threshhold = cutoff_total/num_weeks
print(threshhold)
# Out:
# 312943.3333333333

# %%
print(cutoff_dict)
# Out:
# defaultdict(<class 'int'>, {'180303': 319400, '180310': 331140, '180317': 326500, '180324': 312680, '180331': 313100, '180407': 307220, '180414': 304740, '180421': 311200, '180428': 298400, '180505': 303520, '180512': 303940, '180519': 304520, '180526': 310380, '180602': 311420, '180609': 310340, '180616': 311120, '180623': 322100, '180630': 331260})

# %%
data1 = pd.read_csv('180630.csv')
data1.shape
# Out:
# (196690, 11)

# %%
data1 = data1.where(data1['DESC'] != 'RECOVR AUD').dropna()

# %%
data1['Ent'] = data1['ENTRIES'].diff()
data1 = data1.dropna(axis=0)

# %%
data1 = data1.where(data1['Ent'] >= 0)
data1 = data1.dropna(axis = 0)
data1.shape
# Out:
# (192017, 12)

# %%
# data1.Ent.plot()

# %%
target = math.floor(data1.shape[0]/100)
print(target)
# Out:
# 1920

# %%
cutoff = 0
while data1[data1.Ent > cutoff].count()['Ent'] > target:
    cutoff += 20
    print(cutoff)

print(cutoff)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 332000

# %%
data1[data1.Ent > 331260].count()
# Out:
# C/A                                                                     1920
# UNIT                                                                    1920
# SCP                                                                     1920
# STATION                                                                 1920
# LINENAME                                                                1920
# DIVISION                                                                1920
# DATE                                                                    1920
# TIME                                                                    1920
# DESC                                                                    1920
# ENTRIES                                                                 1920
# EXITS                                                                   1920
# Ent                                                                     1920
# dtype: int64

# %%
data1[data1.Ent < 331260].count()
# Out:
# C/A                                                                     190097
# UNIT                                                                    190097
# SCP                                                                     190097
# STATION                                                                 190097
# LINENAME                                                                190097
# DIVISION                                                                190097
# DATE                                                                    190097
# TIME                                                                    190097
# DESC                                                                    190097
# ENTRIES                                                                 190097
# EXITS                                                                   190097
# Ent                                                                     190097
# dtype: int64
