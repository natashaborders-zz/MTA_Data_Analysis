# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline
import numpy as np

# %%
merged = pd.read_csv('merg_data.csv')

# %%
merged.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   C/A  UNIT       SCP STATION  \
# 0           0             1               1  A002  R051  02-00-00   59 ST
# 1           1             2               2  A002  R051  02-00-00   59 ST
# 2           2             3               3  A002  R051  02-00-00   59 ST
# 3           3             4               4  A002  R051  02-00-00   59 ST
# 4           4             5               5  A002  R051  02-00-00   59 ST
#
#   LINENAME DIVISION        DATE      TIME     DESC  ENTRIES    EXITS    Ent  \
# 0  NQR456W      BMT  2018-02-24  07:00:00  REGULAR  6527794  2210507   14.0
# 1  NQR456W      BMT  2018-02-24  11:00:00  REGULAR  6527838  2210585   44.0
# 2  NQR456W      BMT  2018-02-24  15:00:00  REGULAR  6527994  2210644  156.0
# 3  NQR456W      BMT  2018-02-24  19:00:00  REGULAR  6528278  2210705  284.0
# 4  NQR456W      BMT  2018-02-24  23:00:00  REGULAR  6528389  2210728  111.0
#
#     Ext day_of_week  month
# 0  11.0    Saturday      2
# ...

# %%
merged_data = merged.dropna(axis=0)

# %%
merged_data.to_csv('merg_data.csv')

# %%
merged_data['Ent'].value_counts()
# Out:
#  0.0            453814
#  1.0             52978
#  2.0             38542
#  3.0             34160
#  4.0             31567
#  5.0             29475
#  6.0             28198
#  7.0             26821
#  8.0             26192
#  9.0             24714
#  10.0            23924
#  11.0            23260
#  12.0            22349
#  13.0            21643
#  14.0            21326
#  15.0            20303
#  16.0            19514
#  17.0            18957
#  18.0            18387
#  19.0            17744
#  20.0            17189
#  21.0            16628
#  22.0            16184
#  23.0            15747
#  24.0            15276
#  25.0            14771
#  26.0            14432
#  27.0            14113
#  28.0            13844
#  29.0            13226
#                  ...
# -4286414.0           1
#  4286577.0           1
#  4286810.0           1
# -4287040.0           1
#  4287530.0           1
#  4287647.0           1
#  4287767.0           1
# -4287814.0           1
#  4287875.0           1
# ...

# %%
merged_data.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       ENTRIES         EXITS  \
# count  3.154760e+06  3.154760e+06    3.154760e+06  3.154760e+06  3.154760e+06
# mean   1.577380e+06  1.577380e+06    9.858794e+04  3.927403e+07  3.232718e+07
# std    9.107009e+05  9.107009e+05    5.692249e+04  2.050674e+08  1.900460e+08
# min    0.000000e+00  1.000000e+00    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.886898e+05  7.886908e+05    4.929300e+04  5.081948e+05  2.482708e+05
# 50%    1.577380e+06  1.577380e+06    9.858600e+04  2.577975e+06  1.454429e+06
# 75%    2.366069e+06  2.366070e+06    1.478790e+05  6.890224e+06  4.826487e+06
# max    3.154759e+06  3.154760e+06    1.991150e+05  2.130068e+09  2.145850e+09
#
#                 Ent           Ext         month
# count  3.154760e+06  3.154760e+06  3.154760e+06
# mean  -1.139037e+00 -5.779330e-01  4.177458e+00
# std    4.288098e+07  3.929465e+07  1.111800e+00
# min   -2.117750e+09 -2.145033e+09  2.000000e+00
# ...

# %%
merged_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
merged_data.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
merged_data.drop('Unnamed: 0.1.1', axis=1, inplace=True)

# %%
merged_data.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  07:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  11:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  15:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  19:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  23:00:00
#
#       DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 1  REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 2  REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 3  REGULAR  6528278  2210705  284.0  61.0    Saturday      2
# 4  REGULAR  6528389  2210728  111.0  23.0    Saturday      2

# %%
q25, q50, q75 = np.percentile(merged_data['Ext'],[25,50,75])
iqr=q75-q25
min=q25 -1.5*(iqr)
max=q75 +1.5*(iqr)

print(min, q25, q50, q75, max)
# Out:
# -237.5 7.0 51.0 170.0 414.5

# %%
[x for x in merged_data['Ent'] if x>max]
# Out:
# [750.0,
#  784.0,
#  748.0,
#  729.0,
#  650.0,
#  530.0,
#  579.0,
#  582.0,
#  570.0,
#  544.0,
#  514.0,
#  572.0,
#  562.0,
#  521.0,
#  480.0,
#  5074409.0,
#  572.0,
#  611.0,
#  579.0,
#  586.0,
#  542.0,
#  532.0,
#  551.0,
#  576.0,
#  541.0,
#  504.0,
#  1316176.0,
#  547.0,
#  615.0,
#  594.0,
#  557.0,
#  585.0,
#  4030879.0,
#  428.0,
#  419.0,
#  757.0,
#  425.0,
#  858.0,
#  849.0,
#  424.0,
#  427.0,
#  837.0,
#  696.0,
#  451.0,
#  704.0,
#  486.0,
#  784.0,
#  467.0,
#  741.0,
#  455.0,
#  810.0,
#  420.0,
#  625.0,
#  7413911.0,
#  431.0,
#  428.0,
#  470.0,
#  478.0,
#  429.0,
#  758.0,
#  461.0,
#  804.0,
#  782.0,
#  451.0,
#  823.0,
#  520.0,
#  614.0,
#  1184677.0,
#  736.0,
#  442.0,
#  786.0,
#  768.0,
#  450.0,
#  716.0,
#  539.0,
#  578.0,
#  1244224.0,
#  587.0,
#  583.0,
#  563.0,
#  554.0,
#  466.0,
#  456.0,
#  496.0,
#  479.0,
#  460.0,
#  4704812.0,
#  419.0,
#  425.0,
#  437.0,
#  415.0,
#  1335209.0,
#  567.0,
#  656.0,
#  612.0,
#  583.0,
# ...

# %%
merged_data.loc[merged_data['Ent'] < 0]
# Out:
#            C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 41        A002  R051  02-00-01            59 ST  NQR456W      BMT  2018-02-24
# 83        A002  R051  02-03-00            59 ST  NQR456W      BMT  2018-02-24
# 125       A002  R051  02-03-01            59 ST  NQR456W      BMT  2018-02-24
# 209       A002  R051  02-03-03            59 ST  NQR456W      BMT  2018-02-24
# 335       A002  R051  02-03-06            59 ST  NQR456W      BMT  2018-02-24
# 377       A002  R051  02-05-00            59 ST  NQR456W      BMT  2018-02-24
# 419       A002  R051  02-05-01            59 ST  NQR456W      BMT  2018-02-24
# 503       A006  R079  00-00-00       5 AV/59 ST     NQRW      BMT  2018-02-24
# 632       A006  R079  00-00-03       5 AV/59 ST     NQRW      BMT  2018-02-24
# 761       A006  R079  00-03-01       5 AV/59 ST     NQRW      BMT  2018-02-24
# 847       A007  R079  01-05-00       5 AV/59 ST     NQRW      BMT  2018-02-24
# ...

# %%
merged_data.iloc[3154530:3154560]
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3154530  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154531  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154532  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154533  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154534  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154535  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-13
# 3154536  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-14
# 3154537  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-14
# 3154538  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-14
# 3154539  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-14
# 3154540  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  2018-06-14
# ...

# %%
merged_data.to_csv('cleaned_data_with_outliers.csv')
