# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline
import numpy as np

# %%
merged = pd.read_csv('merg_data.csv')

# %%
merged.head()
# Out:
#    Unnamed: 0   C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24
#
#        TIME        DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  03:00:00  RECOVR AUD  6527780  2210496    NaN   NaN    Saturday      2
# 1  07:00:00     REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 2  11:00:00     REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 3  15:00:00     REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 4  19:00:00     REGULAR  6528278  2210705  284.0  61.0    Saturday      2

# %%
merged_data = merged.dropna(axis=0)

# %%
merged_data.to_csv('merg_data.csv')

# %%
merged_data['Ent'].value_counts()
# Out:
#  0.0            453814
#  1.0             52978
#  2.0             38542
#  3.0             34160
#  4.0             31567
#  5.0             29475
#  6.0             28198
#  7.0             26821
#  8.0             26192
#  9.0             24714
#  10.0            23924
#  11.0            23260
#  12.0            22349
#  13.0            21643
#  14.0            21326
#  15.0            20303
#  16.0            19514
#  17.0            18957
#  18.0            18387
#  19.0            17744
#  20.0            17189
#  21.0            16628
#  22.0            16184
#  23.0            15747
#  24.0            15276
#  25.0            14771
#  26.0            14432
#  27.0            14113
#  28.0            13844
#  29.0            13226
#                  ...
# -4286414.0           1
#  4286577.0           1
#  4286810.0           1
# -4287040.0           1
#  4287530.0           1
#  4287647.0           1
#  4287767.0           1
# -4287814.0           1
#  4287875.0           1
# ...

# %%
merged_data.describe()
# Out:
#          Unnamed: 0       ENTRIES         EXITS           Ent           Ext  \
# count  3.154760e+06  3.154760e+06  3.154760e+06  3.154760e+06  3.154760e+06
# mean   9.858794e+04  3.927403e+07  3.232718e+07 -1.139037e+00 -5.779330e-01
# std    5.692249e+04  2.050674e+08  1.900460e+08  4.288098e+07  3.929465e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00 -2.117750e+09 -2.145033e+09
# 25%    4.929300e+04  5.081948e+05  2.482708e+05  9.000000e+00  7.000000e+00
# 50%    9.858600e+04  2.577975e+06  1.454429e+06  7.400000e+01  5.100000e+01
# 75%    1.478790e+05  6.890224e+06  4.826487e+06  2.510000e+02  1.700000e+02
# max    1.991150e+05  2.130068e+09  2.145850e+09  2.122404e+09  2.145033e+09
#
#               month
# count  3.154760e+06
# mean   4.177458e+00
# std    1.111800e+00
# min    2.000000e+00
# 25%    3.000000e+00
# 50%    4.000000e+00
# 75%    5.000000e+00
# max    6.000000e+00

# %%
q25, q50, q75 = np.percentile(merged_data['Ent'],[25,50,75])
iqr=q75-q25
min=q25 -1.5*(iqr)
max=q75 +1.5*(iqr)

print(min, q25, q50, q75, max)
# Out:
# -354.0 9.0 74.0 251.0 614.0

# %%
[x for x in merged_data['Ent'] if x>max]
# Out:
# [750.0,
#  784.0,
#  748.0,
#  729.0,
#  650.0,
#  5074409.0,
#  1316176.0,
#  615.0,
#  4030879.0,
#  757.0,
#  858.0,
#  849.0,
#  837.0,
#  696.0,
#  704.0,
#  784.0,
#  741.0,
#  810.0,
#  625.0,
#  7413911.0,
#  758.0,
#  804.0,
#  782.0,
#  823.0,
#  1184677.0,
#  736.0,
#  786.0,
#  768.0,
#  716.0,
#  1244224.0,
#  4704812.0,
#  1335209.0,
#  656.0,
#  766.0,
#  845.0,
#  836.0,
#  791.0,
#  640.0,
#  12015743.0,
#  630.0,
#  1050.0,
#  734.0,
#  1101.0,
#  753.0,
#  1015.0,
#  707.0,
#  1037.0,
#  748.0,
#  807.0,
#  3299605.0,
#  115457616.0,
#  712.0,
#  643.0,
#  2279029.0,
#  1016.0,
#  735.0,
#  880.0,
#  744.0,
#  1639.0,
#  717.0,
#  1082.0,
#  752.0,
#  941.0,
#  11120698.0,
#  799.0,
#  1103.0,
#  793.0,
#  695.0,
#  893.0,
#  651.0,
#  811.0,
#  723896.0,
#  775.0,
#  827.0,
#  1055.0,
#  762.0,
#  617.0,
#  1035.0,
#  1226.0,
#  1479.0,
#  1063.0,
#  799.0,
#  16801950.0,
#  719.0,
#  1401.0,
#  753.0,
#  692.0,
#  1654.0,
#  769.0,
#  2130.0,
#  727.0,
#  616.0,
# ...
