# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import seaborn as sns

# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %%
df=pd.read_csv('clean_data.csv')

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  11:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  15:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  19:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  23:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-25  03:00:00
#
#       DESC  ENTRIES    EXITS  month day_of_week    Ent   Ext  sum_ent_ext
# 0  REGULAR  6527838  2210585      2    Saturday   44.0  78.0        122.0
# 1  REGULAR  6527994  2210644      2    Saturday  156.0  59.0        215.0
# 2  REGULAR  6528278  2210705      2    Saturday  284.0  61.0        345.0
# 3  REGULAR  6528389  2210728      2    Saturday  111.0  23.0        134.0
# 4  REGULAR  6528417  2210734      2      Sunday   28.0   6.0         34.0

# %%
by_station = df.groupby('STATION').sum().sort_values(by=['sum_ent_ext'],ascending=True)

# %%
station_data = pd.DataFrame(by_station)
station_data
# Out:
#                        ENTRIES          EXITS   month         Ent         Ext  \
# STATION
# BROAD CHANNEL        859492670      121041576    8247     27522.0      6552.0
# BEACH 105 ST       78633241145     1206775881   13800     19201.0     23647.0
# 163 ST-AMSTERDM    25102766720     9031254942    1194     45205.0     17987.0
# AVENUE I            4938524309   131210385847    8179     49724.0     21629.0
# BEACH 98 ST         3128086707     3373059749   13715     37938.0     38314.0
# ORCHARD BEACH         79241227        4651254    4552     76679.0      5541.0
# ROCKAWAY PARK B    70247392257     7629605234   13877     54559.0     68918.0
# AVENUE P            8509574618     5295463896    8238    122384.0     13891.0
# BEACH 90 ST         3837870464     3946774538   13513     77722.0     61838.0
# BEACH 44 ST         1932789805     2439972761   13730     71805.0     75335.0
# AVENUE N           98300204809     6458028561   19216    154365.0     13241.0
# ...

# %%
by_station_top_ten = station_data.tail(10)

# %%
by_station_top_ten.plot.barh(y='sum_ent_ext')

# %%
by_day_of_week = df.groupby('day_of_week').sum().sort_values(by=['sum_ent_ext'],ascending=True)

# %%
by_day_of_week
# Out:
#                     ENTRIES          EXITS    month          Ent          Ext  \
# day_of_week
# Sunday       11878101444143  8748574135203  1824563   41816131.0   33751439.0
# Monday       11724927979691  8555702843889  1831064   86140204.0   64557075.0
# Wednesday    11680520211717  8453685022981  1860139   91761108.0   69471580.0
# Friday       11681323440929  8486394162375  1923985   92232583.0   70286739.0
# Tuesday      11669723326158  8454750597483  1863424   94696236.0   71209817.0
# Thursday     11639028765725  8451378673903  1887285   96001420.0   72121494.0
# Saturday      9858309212012  7257639364222  1503667  247862882.0  131593773.0
#
#              sum_ent_ext
# day_of_week
# Sunday        75567570.0
# Monday       150697279.0
# Wednesday    161232688.0
# Friday       162519322.0
# Tuesday      165906053.0
# Thursday     168122914.0
# Saturday     379456655.0

# %%
day_of_week = pd.DataFrame(by_day_of_week)

# %%
day_of_week
# Out:
#                     ENTRIES          EXITS    month          Ent          Ext  \
# day_of_week
# Sunday       11878101444143  8748574135203  1824563   41816131.0   33751439.0
# Monday       11724927979691  8555702843889  1831064   86140204.0   64557075.0
# Wednesday    11680520211717  8453685022981  1860139   91761108.0   69471580.0
# Friday       11681323440929  8486394162375  1923985   92232583.0   70286739.0
# Tuesday      11669723326158  8454750597483  1863424   94696236.0   71209817.0
# Thursday     11639028765725  8451378673903  1887285   96001420.0   72121494.0
# Saturday      9858309212012  7257639364222  1503667  247862882.0  131593773.0
#
#              sum_ent_ext
# day_of_week
# Sunday        75567570.0
# Monday       150697279.0
# Wednesday    161232688.0
# Friday       162519322.0
# Tuesday      165906053.0
# Thursday     168122914.0
# Saturday     379456655.0

# %%
day_of_week.plot.barh(y='sum_ent_ext')

# %%
by_time_of_day = df.groupby(['TIME']).sum().sort_values(by=['sum_ent_ext'])

# %%
by_time_of_day.tail(10)
# Out:
#                 ENTRIES          EXITS    month         Ent         Ext  \
# TIME
# 08:00:00  7908144740159  5856884785384  1090073  37619847.0  20396795.0
# 09:00:00  3789106988942  2767152088915   733059  37246576.0  20953479.0
# 13:00:00  3755869820768  2713272891021   733599  32548322.0  26608739.0
# 17:00:00  3742221053190  2725832473431   733335  43537138.0  29932849.0
# 21:00:00  3733635827088  2736615625888   733904  44192046.0  35200503.0
# 01:00:00  3263188671479  2377619762984   633663  56478977.0  34681329.0
# 16:00:00  7905303311657  5846068971802  1090479  62396294.0  45876186.0
# 12:00:00  7897403396718  5843372758147  1089986  69244958.0  57198304.0
# 00:00:00  6782905069493  5029222281170   941854  86750326.0  51075413.0
# 20:00:00  7915039313439  5854246575868  1091005  88644674.0  66764438.0
#
#           sum_ent_ext
# TIME
# 08:00:00   58016642.0
# 09:00:00   58200055.0
# 13:00:00   59157061.0
# 17:00:00   73469987.0
# 21:00:00   79392549.0
# ...

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  11:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  15:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  19:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  23:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-25  03:00:00
#
#       DESC  ENTRIES    EXITS  month day_of_week    Ent   Ext  sum_ent_ext
# 0  REGULAR  6527838  2210585      2    Saturday   44.0  78.0        122.0
# 1  REGULAR  6527994  2210644      2    Saturday  156.0  59.0        215.0
# 2  REGULAR  6528278  2210705      2    Saturday  284.0  61.0        345.0
# 3  REGULAR  6528389  2210728      2    Saturday  111.0  23.0        134.0
# 4  REGULAR  6528417  2210734      2      Sunday   28.0   6.0         34.0

# %%
PENN = df[df['STATION']=='34 ST-PENN STA'].groupby(['day_of_week']).sum()

# %%
PENN
# Out:
#                   ENTRIES         EXITS  month        Ent        Ext  \
# day_of_week
# Friday       386134695998  285933321819  40708  2607355.0  2338879.0
# Monday       384406846992  284615927083  38746  2584411.0  2078011.0
# Saturday     315820846181  233427788634  31638  1150893.0  1118125.0
# Sunday       380511337586  281537065005  38495  1180930.0  1044692.0
# Thursday     380425649970  282135022494  39919  2763027.0  2339823.0
# Tuesday      382577986292  283557459386  39386  2758242.0  2310254.0
# Wednesday    378566660808  280813109464  39241  2635622.0  2226341.0
#
#              sum_ent_ext
# day_of_week
# Friday         4946234.0
# Monday         4662422.0
# Saturday       2269018.0
# Sunday         2225622.0
# Thursday       5102850.0
# Tuesday        5068496.0
# Wednesday      4861963.0

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'month', 'day_of_week', 'Ent', 'Ext',
#        'sum_ent_ext'],
#       dtype='object')

# %%
df.shape
# Out:
# (3035467, 16)

# %%
slim = df.drop(['C/A', 'UNIT', 'SCP','LINENAME', 'DIVISION','DESC', 'ENTRIES', 'EXITS','Ent', 'Ext'], axis=1)

# %%
slim.shape
# Out:
# (3035467, 6)

# %%
slim.groupby('STATION').sum().sort_values(by=['sum_ent_ext'],ascending=False)
# Out:
#                   month  sum_ent_ext
# STATION
# 34 ST-PENN STA   268133   29136605.0
# GRD CNTRL-42 ST  175668   25937115.0
# PATH NEW WTC     117477   24632359.0
# TIMES SQ-42 ST   134236   22037061.0
# JOURNAL SQUARE    56766   21481372.0
# FULTON ST        262982   20482640.0
# 34 ST-HERALD SQ  139267   20351410.0
# GROVE STREET      51444   20037726.0
# 14 ST-UNION SQ   103813   19290379.0
# CANAL ST         156239   18540326.0
# 23 ST            187173   18481887.0
# 42 ST-PORT AUTH  129398   15904995.0
# JFK JAMAICA CT1   27058   15786661.0
# 86 ST            137489   14896281.0
# METS-WILLETS PT   98904   14081041.0
# 125 ST           113032   13314911.0
# LACKAWANNA        59688   13113969.0
# 59 ST COLUMBUS   112142   12881741.0
# 50 ST             98627   12668022.0
# NEWARK BM BW      46825   12113382.0
# 86 ST-2 AVE       41291   12078575.0
# 161/YANKEE STAD   98511   11376537.0
# 14 ST            112174   11194893.0
# 59 ST            136473   11158218.0
# ...

# %%
weekly_schedule = (slim
 .groupby(['day_of_week','STATION'])
 .sum()
 .reset_index())

# %%
weekly_all = pd.DataFrame(weekly_schedule)

# %%
weekly_all.head(5)
# Out:
#   day_of_week        STATION  month  sum_ent_ext
# 0      Friday           1 AV   4140     777814.0
# 1      Friday         103 ST   6525     878453.0
# 2      Friday  103 ST-CORONA   3770     547511.0
# 3      Friday         104 ST   2527      63033.0
# 4      Friday         110 ST   2484     330586.0

# %%
by_day = weekly_all.set_index('day_of_week')

# %%
by_day.head()
# Out:
#                    STATION  month  sum_ent_ext
# day_of_week
# Friday                1 AV   4140     777814.0
# Friday              103 ST   6525     878453.0
# Friday       103 ST-CORONA   3770     547511.0
# Friday              104 ST   2527      63033.0
# Friday              110 ST   2484     330586.0
