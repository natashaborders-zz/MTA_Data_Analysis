# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline
import numpy as np

# %%
final_data = pd.read_csv('final_data.csv')

# %%
final_data.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  07:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  11:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  15:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  19:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2018-02-24  23:00:00
#
#       DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 1  REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 2  REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 3  REGULAR  6528278  2210705  284.0  61.0    Saturday      2
# 4  REGULAR  6528389  2210728  111.0  23.0    Saturday      2

# %%
final_data.groupby(['STATION', 'day_of_week', 'TIME']).mean().sort_values(['Ent', 'Ext'], ascending = [False,False])
# Out:
#                                            ENTRIES         EXITS  \
# STATION         day_of_week TIME
# DITMAS AV       Saturday    01:00:00  7.911382e+07  1.918618e+04
#                             00:00:00  9.239040e+07  2.488100e+04
# SUTPHIN BLVD    Saturday    01:00:00  2.919197e+07  2.552203e+05
#                             00:00:00  2.916163e+07  2.451403e+05
# 168 ST          Saturday    03:00:00  2.630545e+07  1.922988e+05
# 23 ST           Saturday    03:00:00  8.052567e+07  1.538475e+06
# 168 ST          Saturday    00:00:00  2.417472e+07  1.854746e+05
# 14 ST           Saturday    01:00:00  1.218259e+08  1.320892e+06
# 23 ST           Saturday    00:00:00  5.722886e+07  2.260433e+06
# 149/GRAND CONC  Saturday    00:00:00  8.834383e+06  2.088475e+05
# JAMAICA 179 ST  Saturday    00:00:00  1.043017e+07  1.103347e+05
#                             03:00:00  1.036716e+07  1.097212e+05
# 149/GRAND CONC  Saturday    03:00:00  8.659762e+06  1.033633e+05
# ...

# %%
final_data.Ext.plot()

# %%
sns.pairplot(final_data)

# %%
final_data.groupby('STATION')[['Ext']].sum().sort_values(by = 'Ext', ascending=False)
# Out:
#                         Ext
# STATION
# PATH NEW WTC     37211337.0
# 34 ST-PENN STA   21976376.0
# CITY / BUS       20120879.0
# HOWARD BCH JFK   16258107.0
# GRD CNTRL-42 ST  16133723.0
# ATL AV-BARCLAY   15962555.0
# 23 ST            15183294.0
# JAY ST-METROTEC  14853432.0
# FULTON ST        14184746.0
# JOURNAL SQUARE   14047843.0
# GROVE STREET     13649990.0
# 161/YANKEE STAD  13461731.0
# METS-WILLETS PT  12643900.0
# PAVONIA/NEWPORT  11635986.0
# 47-50 STS ROCK   11281264.0
# WALL ST          11133476.0
# TIMES SQ-42 ST   10631660.0
# 34 ST-HERALD SQ   9803910.0
# EXCHANGE PLACE    9655468.0
# 59 ST COLUMBUS    9459819.0
# 14 ST             9393751.0
# 42 ST-BRYANT PK   9352906.0
# 86 ST-2 AVE       9232259.0
# B'WAY-LAFAYETTE   9210265.0
# 14 ST-UNION SQ    9015730.0
# 231 ST            9010357.0
# JACKSON AV        8931542.0
# CANAL ST          8784360.0
# CORTLANDT ST      8777985.0
# CHURCH AV         8564650.0
# ...                     ...
# BUSHWICK AV        167902.0
# ...
