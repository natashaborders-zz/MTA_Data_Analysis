# %%
import pandas as pd
import matplotlib as mp
import seaborn as sns
import time

# %%
data1 = pd.read_csv('data_files/file1.csv')

# %%
data2 = pd.read_csv('data_files/file2.csv')

# %%
data3 = pd.read_csv('data_files/file3.csv')

# %%
data4 = pd.read_csv('data_files/file4.csv')

# %%
data5 = pd.read_csv('data_files/file5.csv')

# %%
data6 = pd.read_csv('data_files/file6.csv')

# %%
data7 = pd.read_csv('data_files/file7.csv')

# %%
data8 = pd.read_csv('data_files/file8.csv')

# %%
data9 = pd.read_csv('data_files/file9.csv')

# %%
data10 = pd.read_csv('data_files/file10.csv')

# %%
data11 = pd.read_csv('data_files/file11.csv')

# %%
data12 = pd.read_csv('data_files/file12.csv')

# %%
data13 = pd.read_csv('data_files/file13.csv')

# %%
data14 = pd.read_csv('data_files/file14.csv')

# %%
data15 = pd.read_csv('data_files/file15.csv')

# %%
data16 = pd.read_csv('data_files/file16.csv')

# %%
frames = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16]

# %%
merg=pd.concat(frames)

# %%
merg['turnstile_id'] = merg['C/A'] + merg['UNIT'] + merg['SCP']

# %%
merg['EXITS']=merg['EXITS                                                               ']

# %%
del merg['EXITS                                                               ']

# %%
merg['Ent'] = merg['ENTRIES'] - merg['ENTRIES'].shift(+1)

# %%
merg['Ext'] = merg['EXITS'] - merg['EXITS'].shift(+1)

# %%
list_turn = merg['turnstile_id']
for i, val in enumerate(list_turn[1:]):
    if val != list_turn[i]:
        merg.loc[(i+1), 'Ent'] = np.nan
        
merg.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-a7ebc8d4b4da> in <module>
#       1 list_turn = merg['turnstile_id']
#       2 for i, val in enumerate(list_turn[1:]):
# ----> 3     if val != list_turn[i]:
#       4         merg.loc[(i+1), 'Ent'] = np.nan
#       5
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
merg['DATE']=pd.to_datetime(merg['DATE'])
merg['day_of_week'] = merg['DATE'].dt.weekday_name

# %%
merg['month']=merg['DATE'].dt.month

# %%
merg.dropna(axis=0)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-24
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-25
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT 2018-02-26
# ...

# %%
merg.to_csv('merg_data.csv', index=False)
