# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline
import numpy as np

# %%
cleaned_data_with_outliers = pd.read_csv('merg_data.csv')

# %%
cleaned_data_with_outliers.head(5)
# Out:
#     C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00  59 STNQR456W  NQR456W      BMT  2018-02-24  03:00:00
# 1  A002  R051  02-00-00  59 STNQR456W  NQR456W      BMT  2018-02-24  07:00:00
# 2  A002  R051  02-00-00  59 STNQR456W  NQR456W      BMT  2018-02-24  11:00:00
# 3  A002  R051  02-00-00  59 STNQR456W  NQR456W      BMT  2018-02-24  15:00:00
# 4  A002  R051  02-00-00  59 STNQR456W  NQR456W      BMT  2018-02-24  19:00:00
#
#          DESC  ENTRIES    EXITS    Ent   Ext day_of_week  month
# 0  RECOVR AUD  6527780  2210496    NaN   NaN    Saturday      2
# 1     REGULAR  6527794  2210507   14.0  11.0    Saturday      2
# 2     REGULAR  6527838  2210585   44.0  78.0    Saturday      2
# 3     REGULAR  6527994  2210644  156.0  59.0    Saturday      2
# 4     REGULAR  6528278  2210705  284.0  61.0    Saturday      2

# %%
cleaned_data_without_recover = cleaned_data_with_outliers[cleaned_data_with_outliers['DESC']!='RECOVR AUD']

# %%
cleaned_data_without_outliers = cleaned_data_with_outliers[cleaned_data_with_outliers['Ent']>=0]

# %%
cleaned_data_completely = cleaned_data_without_outliers[cleaned_data_without_outliers['Ext']>=0]

# %%
cleaned_data_completely.describe()
# Out:
#             ENTRIES         EXITS           Ent           Ext         month
# count  3.073366e+06  3.073366e+06  3.073366e+06  3.073366e+06  3.073366e+06
# mean   2.697362e+07  1.977371e+07  7.483926e+05  6.509526e+05  4.179115e+00
# std    1.550373e+08  1.340907e+08  2.997292e+07  2.770548e+07  1.111222e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  2.000000e+00
# 25%    5.009342e+05  2.445822e+05  1.000000e+01  8.000000e+00  3.000000e+00
# 50%    2.533404e+06  1.422786e+06  7.800000e+01  5.300000e+01  4.000000e+00
# 75%    6.738118e+06  4.701100e+06  2.540000e+02  1.720000e+02  5.000000e+00
# max    2.130068e+09  2.145850e+09  2.122404e+09  2.145033e+09  6.000000e+00

# %%
cleaned_data_no_max_Ent=cleaned_data_completely[cleaned_data_completely.Ent<=312943]

# %%
cleaned_data_no_max_Ext = cleaned_data_no_max_Ent[cleaned_data_no_max_Ent.Ext<=143941]

# %%
cleaned_data_no_max_Ext.describe()
# Out:
#             ENTRIES         EXITS           Ent           Ext         month
# count  3.046771e+06  3.046771e+06  3.046771e+06  3.046771e+06  3.046771e+06
# mean   2.640224e+07  1.923788e+07  2.463938e+02  1.684327e+02  4.180147e+00
# std    1.526831e+08  1.315598e+08  3.368434e+03  1.618189e+03  1.110871e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  2.000000e+00
# 25%    4.930970e+05  2.399370e+05  1.000000e+01  8.000000e+00  3.000000e+00
# 50%    2.498293e+06  1.405167e+06  7.600000e+01  5.200000e+01  4.000000e+00
# 75%    6.686318e+06  4.664228e+06  2.470000e+02  1.670000e+02  5.000000e+00
# max    2.115507e+09  2.049871e+09  3.126280e+05  1.438600e+05  6.000000e+00

# %%
cleaned_data_no_max_Ext.Ent.plot()

# %%
cleaned_data_no_max_Ext.to_csv('final_data.csv',index=False)
